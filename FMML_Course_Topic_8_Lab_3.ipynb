# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhath-basava/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-10 02:59:20--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  92.1MB/s    in 0.7s
#
# 2023-05-10 02:59:21 (92.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22405  1606.00118v1  In genome-wide interaction studies, to detect ...  stat
# 13150  1706.07719v1  Suppose, we are given a set of $n$ elements to...  stat
# 7174   1710.10570v2  Deep neural networks (DNNs) form the backbone ...    cs
# 23051  1802.08163v1  Distributional approaches to value-based reinf...  stat
# 7914   1501.06633v3  This paper describes maxDNN, a computationally...    cs
# ...             ...                                                ...   ...
# 6123   1607.08810v1  Polynomial networks and factorization machines...  stat
# 17152  1708.09803v2  We present a simple method to improve neural t...    cs
# 21497   0706.3499v1  The distance metric plays an important role in...  stat
# 40122  1711.05535v2  This paper considers the task of matching imag...    cs
# 16709  1705.03247v1  Prosody describes both form and function of a ...    cs
#
#                                                    title  year  \
# 22405  Gene-Gene association for Imaging Genetics Dat...  2016
# 13150  Query Complexity of Clustering with Side Infor...  2017
# 7174   Weight Initialization of Deep Neural Networks(...  2017
# 23051  An Analysis of Categorical Distributional Rein...  2018
# 7914   maxDNN: An Efficient Convolution Kernel for De...  2015
# ...                                                  ...   ...
# 6123   Polynomial Networks and Factorization Machines...  2016
# 17152  Transfer Learning across Low-Resource, Related...  2017
# 21497  Metric Embedding for Nearest Neighbor Classifi...  2007
# 40122       Dual-Path Convolutional Image-Text Embedding  2017
# 16709               A Systematic Review of Hindi Prosody  2017
#
#                                                 keywords
# 22405  [interaction, interactions, nucleotide, polymo...
# 13150  [clustered, oracleexpert, interactively, clust...
# 7174   [technique, processing, computational, technol...
# 23051  [distributional, approaches, reinforcement, di...
# 7914   [describes, computationally, efficient, convol...
# ...                                                  ...
# 6123   [polynomial, factorization, efficiently, inter...
# 17152  [translation, vocabulary, vocabulary, paramete...
# 21497  [important, classification, euclidean, mahalan...
# 40122  [considers, sentences, challenge, discriminati...
# 16709  [describes, suprasegmental, phenomena, phonolo...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22405    [interaction, interactions, nucleotide, polymo...
# 13150    [clustered, oracleexpert, interactively, clust...
# 7174     [technique, processing, computational, technol...
# 23051    [distributional, approaches, reinforcement, di...
# 7914     [describes, computationally, efficient, convol...
#                                ...
# 31075    [laboriously, convenient, signifies, alternati...
# 10523    [sequential, techniques, estimation, approxima...
# 36245    [negotiation, environment, performance, strate...
# 21784    [synthetic, optimization, designing, character...
# 38678    [scientific, disciplines, characterized, compa...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8656 words.
# Out of those 4540 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f634d88b-d104-49f9-a4bd-2463996989e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f634d88b-d104-49f9-a4bd-2463996989e6")) {                    Plotly.newPlot(                        "f634d88b-d104-49f9-a4bd-2463996989e6",                        [{"x":["sensitive","statistic","classical","nucleotide","canonical","resampling","interactions","computationally","correlation","intensive","contaminated","therefore","interaction","basically","polymorphisms","nonparametric","demonstrate","relationship","nonlinear","investigate","operators","covariance","association","performance","influence","effective","synthesized","connection","contribution","parameter","algorithms","generalizes","stochastic","hellinger","divergence","similarity","theoretical","theoretic","attributes","distribution","intriguing","detection","drastically","clustering","knowledge","automated","complexity","community","represents","otherwise","information","logarithmically","interesting","probability","arbitrary","independently","interactive","clustered","underlying","interactively","significantly","relationships","efficient","overwhelming","statistics","initializing","difficult","technique","optimizing","experiments","performances","technology","practical","initialization","processing","researchers","providing","approaches","variables","challenges","performed","dimensional","objective","computational","vanishing","suggested","sophisticated","techniques","classification","dependent","connections","projected","convergence","properties","empirical","fundamental","demonstrated","establish","importance","distributional","categorical","understood","framework","algorithm","reinforcement","introduce","convolution","efficiency","operation","propagation","describes","architectures","structured","counterparts","generalization","structure","classifying","specified","explicitly","recurrent","appropriate","performing","crucially","generative","probabilistic","variational","supervision","decomposing","inference","inferences","partially","understanding","processes","supervised","previously","requirement","compactly","supported","expectation","functions","increasing","alongside","approximately","drawbacks","posterior","alleviated","regression","computations","substantial","implementation","attractive","perception","unobserved","accessing","handcrafted","discriminatively","identities","perceptron","viewpoints","intriguingly","interpolate","representation","disentangling","different","recognize","representations","meanwhile","recognition","challenge","illuminations","positions","convolutional","transformer","mechanism","extending","distances","efficiently","combining","introduced","respectively","attention","alternative","mechanisms","generalize","improvement","translation","improvements","according","relations","occurring","comprehensive","prediction","retrieval","unconstrained","autocorrelation","constraints","scalability","application","flexibility","effectiveness"],"y":[59,7,88,0,22,6,67,81,78,30,7,156,90,4,0,12,582,73,55,124,48,27,26,897,59,247,14,53,48,114,612,37,146,1,28,136,185,40,69,208,7,354,11,143,340,96,219,89,43,19,704,4,66,173,77,46,36,17,122,4,261,71,424,3,52,4,152,235,38,602,42,53,142,21,288,80,85,432,118,112,122,167,168,278,4,28,20,397,498,79,44,20,124,209,155,88,93,51,76,19,6,18,539,808,100,346,46,153,48,71,83,124,106,20,111,326,38,32,74,155,61,87,6,100,188,55,57,10,210,11,40,148,109,237,86,32,6,17,18,196,101,7,34,14,42,5,111,24,47,135,19,45,7,6,11,10,8,18,9,2,1,351,5,760,41,230,16,381,140,2,21,414,9,104,27,35,169,107,134,92,163,89,60,59,159,116,126,104,98,27,69,241,104,19,2,159,37,258,33,207],"type":"bar"},{"x":["sensitive","statistic","classical","nucleotide","canonical" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4540,), (4540, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.75);'>Superpixels</span> <span style=''>Based</span> <span style=''>Marker</span> <span style=''>Tracking</span> <span style=''>Vs</span> <span style=''>Hue</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Thresholding</span> <span style=''>In</span> <span style=''>Rodent</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Biomechanics</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>Examining</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>locomotion</span> <span style=''>has</span> <span style=''>improved</span> <span style=''>our</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>motor</span> <span style=''>control</span> <span style=''>and</span> <span style=''>aided</span> <span style=''>in</span> <span style=''>treating</span> <span style=''>motor</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>impairment</span> <span style=''>Mice</span> <span style=''>and</span> <span style=''>rats</span> <span style=''>are</span> <span style=''>premier</span> <span style=''>models</span> <span style=''>of</span> <span style=''>human</span> <span style=''>disease</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasingly</span> <span style=''>the</span> <span style=''>model</span> <span style=''>systems</span> <span style=''>of</span> <span style=''>choice</span> <span style=''>for</span> <span style=''>basic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neuroscience</span> <span style=''>High</span> <span style=''>frame</span> <span style=''>rates</span> <span style=''>(250</span> <span style=''>Hz)</span> <span style=''>are</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>kinematics</span> <span style=''>of</span> <span style=''>these</span> <span style=''>running</span> <span style=''>rodents</span> <span style=''>Manual</span> <span style=''>tracking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>for</span> <span style=''>multiple</span> <span style=''>markers</span> <span style=''>becomes</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consuming</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impossible</span> <span style=''>for</span> <span style=''>large</span> <span style=''>sample</span> <span style=''>sizes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Therefore</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5843137254901961);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.7251908396946565);'>segmentation</span> <span style=''>of</span> <span style=''>these</span> <span style=''>markers</span> <span style=''>has</span> <span style=''>grown</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>two</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>segment</span> <span style=''>and</span> <span style=''>track</span> <span style=''>these</span> <span style=''>markers</span> <span style=''>first</span> <span style=''>using</span> <span style=''>SLIC</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>superpixels</span> <span style='background-color:rgba(0, 255, 0, 0.7251908396946565);'>segmentation</span> <span style=''>with</span> <span style=''>a</span> <span style=''>tracker</span> <span style=''>based</span> <span style=''>on</span> <span style=''>position ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Way</span> <span style=''>Multi</span> <span style=''>View</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>extend</span> <span style=''>multi</span> <span style=''>way</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>ANOVA</span> <span style=''>type</span> <span style=''>analysis</span> <span style=''>to</span> <span style=''>cases</span> <span style=''>where</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariate</span> <span style=''>is</span> <span style=''>the</span> <span style=''>view</span> <span style=''>with</span> <span style=''>features</span> <span style=''>of</span> <span style=''>each</span> <span style=''>view</span> <span style=''>coming</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>domains</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>views</span> <span style=''>are</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>by</span> <span style=''>having</span> <span style=''>paired</span> <span style=''>samples</span> <span style=''>this</span> <span style=''>is</span> <span style=''>a</span> <span style=''>common</span> <span style=''>setup</span> <span style=''>in</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bioinformatics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>of</span> <span style=''>which</span> <span style=''>we</span> <span style=''>analyze</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>metabolite</span> <span style=''>profiles</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>(disease</span> <span style=''>vs</span> <span style=''>control</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>vs</span> <span style=''>untreated)</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>tissues</span> <span style=''>(views)</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>way</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>model</span> <span style=''>for</span> <span style=''>this</span> <span style=''>new</span> <span style=''>task</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>analysis</span> <span style=''>(CCA)</span> <span style=''>both</span> <span style=''>to</span> <span style=''>take</span> <span style=''>multi</span> <span style=''>way</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>into</span> <span style=''>account</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>priors</span> <span style=''>and</span> <span style=''>by</span> <span style=''>reducing</span> <span style=''>the</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Testing</span> <span style=''>whether</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.4181818181818182);'>equations</span> <span style=''>are</span> <span style=''>causal</span> <span style=''>A</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>theory</span> <span style=''>approach</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>that</span> <span style=''>infers</span> <span style=''>whether</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.53125);'>relations</span> <span style=''>between</span> <span style=''>two</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.39492753623188404);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.4129353233830846);'>variables</span> <span style=''>X</span> <span style=''>and</span> <span style=''>Y</span> <span style=''>are</span> <span style=''>due</span> <span style=''>to</span> <span style=''>a</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>from</span> <span style=''>X</span> <span style=''>to</span> <span style=''>Y</span> <span style=''>or</span> <span style=''>from</span> <span style=''>Y</span> <span style=''>to</span> <span style=''>X</span> <span style=''>The</span> <span style=''>earlier</span> <span style=''>proposed</span> <span style=''>so</span> <span style=''>called</span> <span style=''>Trace</span> <span style=''>Method</span> <span style=''>is</span> <span style=''>extended</span> <span style=''>to</span> <span style=''>the</span> <span style=''>regime</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3705583756345178);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>observed</span> <span style='background-color:rgba(255, 0, 0, 0.4129353233830846);'>variables</span> <span style=''>exceeds</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>postulate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>a</span> <span style=''>causal</span> <span style=''>relation</span> <span style=''>between</span> <span style=''>X</span> <span style=''>and</span> <span style=''>Y</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3114754098360655);'>statistical</span> <span style=''>test</span> <span style=''>and</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>both</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>rejected</span> <span style=''>if</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>common</span> <span style=''>cause</span> <span style=''>A</span> <span style=''>full</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3183520599250936);'>presented</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style=''>case</span> <span style=''>but</span> <span style=''>our</span> <span style=''>approa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>New</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Building</span> <span style=''>the</span> <span style=''>Interindustry</span> <span style=''>Input</span> <span style=''>Output</span> <span style=''>Table</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interdependence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industries</span> <span style=''>in</span> <span style=''>an</span> <span style=''>economy</span> <span style=''>by</span> <span style=''>applying</span> <span style=''>data</span> <span style=''>science</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploiting</span> <span style=''>interfirm</span> <span style=''>buyer</span> <span style=''>seller</span> <span style=''>network</span> <span style=''>data</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interdependence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industries</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncovering</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>block</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>network</span> <span style=''>science</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>To</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>with</span> <span style=''>greater</span> <span style=''>accuracy</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>block</span> <span style=''>model</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporates</span> <span style=''>node</span> <span style=''>textual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unbounded</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industries</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>among</span> <span style=''>them</span> <span style=''>The</span> <span style=''>latter</span> <span style=''>task</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accomplished</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restaurant</span> <span style=''>process</span> <span style=''>to</span> <span style=''>two</span> <span style='background-color:rgba(0, ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12112575703598147)
# 	automatic (0.07196294976843605)
# 	processing (0.10260064125400783)
# 	architecture (0.08870680441752761)
# 	information (0.25080156750979693)
# 	segmentation (0.08051300320627004)
# 	detection (0.1261132882080513)
# 	different (0.2707516921980762)
# 	recognition (0.13573209832561453)
# 	convolutional (0.14748842180263627)
#
# Some Statistics words are:
# 	distributions (0.12042147516307075)
# 	theoretical (0.1620672353236327)
# 	estimation (0.1741093828399398)
# 	variables (0.14249874560963371)
# 	statistical (0.16056196688409433)
# 	algorithm (0.3933768188660311)
# 	inference (0.18665328650275967)
# 	distribution (0.19869543401906672)
# 	dimensional (0.193176116407426)
# 	regression (0.1851480180632213)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="00908c75-ba8e-4752-81df-0bc8c1d14c68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00908c75-ba8e-4752-81df-0bc8c1d14c68")) {                    Plotly.newPlot(                        "00908c75-ba8e-4752-81df-0bc8c1d14c68",                        [{"x":["sensitive","statistic","classical","nucleotide","canonical","resampling","interactions","computationally","correlation","intensive","contaminated","therefore","interaction","basically","polymorphisms","nonparametric","demonstrate","relationship","nonlinear","investigate","operators","covariance","association","performance","influence","effective","synthesized","connection","contribution","parameter","algorithms","generalizes","stochastic","hellinger","divergence","similarity","theoretical","theoretic","attributes","distribution","intriguing","detection","drastically","clustering","knowledge","automated","complexity","community","represents","otherwise","information","logarithmically","interesting","probability","arbitrary","independently","interactive","clustered","underlying","interactively","significantly","relationships","efficient","overwhelming","statistics","initializing","difficult","technique","optimizing","experiments","performances","technology","practical","initialization","processing","researchers","providing","approaches","variables","challenges","performed","dimensional","objective","computational","vanishing","suggested","sophisticated","techniques","classification","dependent","connections","projected","convergence","properties","empirical","fundamental","demonstrated","establish","importance","distributional","categorical","understood","framework","algorithm","reinforcement","introduce","convolution","efficiency","operation","propagation","describes","architectures","structured","counterparts","generalization","structure","classifying","specified","explicitly","recurrent","appropriate","performing","crucially","generative","probabilistic","variational","supervision","decomposing","inference","inferences","partially","understanding","processes","supervised","previously","requirement","compactly","supported","expectation","functions","increasing","alongside","approximately","drawbacks","posterior","alleviated","regression","computations","substantial","implementation","attractive","perception","unobserved","accessing","handcrafted","discriminatively","identities","perceptron","viewpoints","intriguingly","interpolate","representation","disentangling","different","recognize","representations","meanwhile","recognition","challenge","illuminations","positions","convolutional","transformer","mechanism","extending","distances","efficiently","combining","introduced","respectively","attention","alternative","mechanisms","generalize","improvement","translation","improvements","according","relations","occurring","comprehensive","prediction","retrieval","unconstrained","autocorrelation","constraints","scalability","application","flexibility","effectiveness","relational","successive","estimation","difficulty","consequently","localization","contextual","obtaining","distinguishing","segmentation","extracting","categories","experimentation","transitive","challenging","currently","dynamically","frequencies","participating","communities","predictable","displaying","influential","determined","existence","component","consisting","quantitative","discussion","dominating","measuring","highlight","metaheuristic","landscapes","landscape","evolvability","neutrality","characteristic","additional","presented","capability","countermeasures","developed","imitation","artificial","analogies","evolution","separately","benchmark","conditions","codebooks","attracted","experimental","maximizing","histog ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nucleotide
# 	polymorphisms
# 	unmeasured
# 	equivalences
# 	seasonality
# 	polylogarithmic
# 	modulating
# 	parameterizes
# 	economists
# 	fmathcalx
# 	discretizations
# 	precipitation
# 	explainability
# 	debiasing
# 	recommended
# 	amortization
# 	hausdorff
# 	nonparanormal
# 	bernstein
# 	kontorovich
# Some words which never appear in Statistics papers:
# 	illuminations
# 	transformer
# 	dominating
# 	metaheuristic
# 	evolvability
# 	countermeasures
# 	imitation
# 	analogies
# 	codebooks
# 	transferring
# 	articulated
# 	eligibility
# 	nonvolatile
# 	resistive
# 	illumination
# 	lifschitz
# 	flickering
# 	textitdeep
# 	replicates
# 	histopathology

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0665440049064704e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
